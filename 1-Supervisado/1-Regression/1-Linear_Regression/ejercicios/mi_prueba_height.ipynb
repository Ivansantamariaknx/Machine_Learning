# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Objetivo: predecir el peso de 5 personas random

# %%
altura = pd.read_csv(r"C:\Users\Abraham\Desktop\Solo\Bootcamp\Machine_Learning\1-Supervisado\1-Regression\1-Linear_Regression\data\altura500.csv")
altura
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
altura['Genero'] = altura['Gender'].apply(lambda x: 1 if x == 'Male' else 0)

# %%
altura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
#  4   Genero  500 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 19.7+ KB

# %%
altura.describe()
# Out:
#            Height      Weight       Index      Genero
# count  500.000000  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000    0.490000
# std     16.375261   32.382607    1.355053    0.500401
# min    140.000000   50.000000    0.000000    0.000000
# 25%    156.000000   80.000000    3.000000    0.000000
# 50%    170.500000  106.000000    4.000000    0.000000
# 75%    184.000000  136.000000    5.000000    1.000000
# max    199.000000  160.000000    5.000000    1.000000

# %%
altura.corr()
# Out:
#           Height    Weight     Index    Genero
# Height  1.000000  0.000446 -0.422223 -0.017677
# Weight  0.000446  1.000000  0.804569  0.009523
# Index  -0.422223  0.804569  1.000000  0.028786
# Genero -0.017677  0.009523  0.028786  1.000000

# %%
sns.pairplot(altura)

# %%
#vemos la distribución de nuestra variable

sns.distplot(altura['Weight']);
# Out:
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.heatmap(altura.corr(), annot=True);

# %%
# Definir variables del modelo

# %%
altura.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index', 'Genero'], dtype='object')

# %%
x=altura[['Height', 'Index', 'Genero']]
y=altura[["Weight"]]

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train,y_test=train_test_split(x,y, test_size=0.30, random_state=50)
